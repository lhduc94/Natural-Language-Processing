# %% [markdown]
# # Import Thư viện

# %%
import pandas as pd
import re
from nltk import ngrams
from pyvi.pyvi import ViTokenizer

# %% [markdown]
# # Load dữ liệu train và stopwords

# %%
df = pd.read_csv('dataNLP.csv', header=None,names=['index','title','description'])
f = open('stopwords.txt','r')
stopwords = ['tập)', '(phần','dù',"div",'một','hai','ba','bốn','năm','sáu','bảy','tám','chín','mười']
for word in f:
    stopwords.append(word.strip()+ ' ')
f.close()
df.head(20)
# Out:
#         index                                              title  \
# 0   100000008                   cô dâu 15 tuổi (my little bride)
# 1   100000019      thất đại tội (24 tập) (the seven deadly sins)
# 2   100000026  cô gái ngoài hành tinh (13 tập) (brynhildr in ...
# 3   100000031               10 phần yêu (love is not all around)
# 4   100000042  lớp học ám sát (phần 2) (assassination classro...
# 5   100000050         những giây cuối cùng (the final countdown)
# 6   100000054  vua bịp đại chiến las vegas (the conmen in vegas)
# 7   100000059                            vì yêu (a view of love)
# 8   100000061                  cớm lưu manh (untouchable lawmen)
# 9   100000069               yêu không dễ (64 tập) (yeu khong de)
# 10  100000071  em gái hai mặt (12 tập) (my two-faced little s...
# 11  100000072  cao bồi đại chiến khủng long (cowboys vs dinos...
# 12  100000080       mat-xcơ-va tình yêu của tôi (moscow my love)
# 13  100000100  hội pháp sư ngoại truyện (10 tập) (fairy tail ...
# 14  100000115     thám tử sói (12 tập) (cuticle detective inaba)
# 15  100000117          cuộc giải cứu cuối cùng (the last rescue)
# 16  100000142                  bản tin trang nhất (a-1 headline)
# 17  100000143             chấp pháp tiên phong (righting wrongs)
# 18  100000148  kẻ trộm mộ: huyền thoại trở lại (mojin - the l...
# 19  100000162  những ngày cuối chuyến lưu diễn (the end of th...
#
#                                           description
# 0   sang min là dân mỹ thuật, tính đào hoa thích t...
# 1   24 tập phim theo chân elizabeth, công chúa thứ...
# 2   murakami luôn bị ám ảnh vì đã để người bạn thu...
# 3   dù là cô nàng "sát giai", có nhiều mánh lới "d...
# 4   các học sinh lớp 3e-1 bước vào học kỳ thứ hai....
# 5   năm 1980, trong lúc tập trận ở hawaii, một cơn...
# 6   tài tử điện ảnh số một hồng kông tiếp tục có m...
# 7   marc sở hữu gần như mọi thứ mà một người đàn ô...
# 8   lee jung jin, một cảnh sát nắm đấm đi trước lờ...
# 9   quy tụ dàn diễn viên “hot”, phim xoay quanh nh...
# 10  umaru là một cô "hot girl" xinh đẹp mới 16 tuổ...
# 11  sau một vụ nổ mỏ, loài khủng long tưởng như đã...
# 12  bản tình ca tuyệt đẹp ca ngợi mối tình không b...
# 13  chuyển thể từ phần ngoại truyện của bộ truyện ...
# 14  được lai tạo giữa người và sói, hiroshi có khả...
# 15  không bao lâu sau ngày đổ bộ, ba người người l...
# 16  bạn trai của ling đột ngột qua đời trong một t...
# 17  do bất mãn trước việc pháp luật dường như bảo ...
# 18  là phim được trông đợi nhất nhì năm 2015 vì đư...
# 19  phim kể về cuộc phỏng vấn kéo dài năm ngày giữ...

# %% [markdown]
# # Tiền xử lý dữ liệu

# %%
def transform_row(row,_stopwords=1):
    # Xóa số dòng ở đầu câu
    row = row.split("(")[0]
    row = re.sub(r"[0-9]", "", row)
    if stopwords ==1 :
        for word in stopwords:
            row = row.replace(word,"")
    # Xóa dấu chấm, phẩy, hỏi ở cuối câu
    row = re.sub(r"[\.,\?]+$", "", row)
    # Xóa các kí tự khác
    char = ''',.;":'?!()-<>/'''
    for c in char:
        row = row.replace(c," ")
    row = row.replace(",", " ").replace(".", " ") \
        .replace(";", " ").replace("“", " ") \
        .replace(":", " ").replace("”", " ") \
        .replace('"', " ").replace("'", " ") \
#         .replace("!", " ").replace("?", " ") \
#         .replace("(", " ").replace(")", " ") \
#         .replace("-"," ").replace("div"," ") \
#         .replace("<"," ").replace(">"," ") \

    row = row.strip()
    return row 
s1 = u'ÀÁÂÃÈÉÊÌÍÒÓÔÕÙÚÝàáâãèéêìíòóôõùúýĂăĐđĨĩŨũƠơƯưẠạẢảẤấẦầẨẩẪẫẬậẮắẰằẲẳẴẵẶặẸẹẺẻẼẽẾếỀềỂểỄễỆệỈỉỊịỌọỎỏỐốỒồỔổỖỗỘộỚớỜờỞởỠỡỢợỤụỦủỨứỪừỬửỮữỰựỲỳỴỵỶỷỸỹ'
s0 = u'AAAAEEEIIOOOOUUYaaaaeeeiioooouuyAaDdIiUuOoUuAaAaAaAaAaAaAaAaAaAaAaAaEeEeEeEeEeEeEeEeIiIiOoOoOoOoOoOoOoOoOoOoOoOoUuUuUuUuUuUuUuYyYyYyYy'
def remove_accents(input_str):
    s = ''
    for c in input_str.decode('utf-8'):
        if c in s1:
            s += s0[s1.index(c)]
        else:
            s += c
    return s

df['title'] = df.title.apply(transform_row)
df['description'] = df.description.apply(transform_row)
df.head(20)
# Out:
#         index                         title  \
# 0   100000008                  cô dâu  tuổi
# 1   100000019                  thất đại tội
# 2   100000026        cô gái ngoài hành tinh
# 3   100000031                      phần yêu
# 4   100000042                lớp học ám sát
# 5   100000050                     giây cuối
# 6   100000054   vua bịp đại chiến las vegas
# 7   100000059                           yêu
# 8   100000061                  cớm lưu manh
# 9   100000069                        yêu dễ
# 10  100000071                   em gái  mặt
# 11  100000072  cao bồi đại chiến khủng long
# 12  100000080       mat xcơ va tình yêu tôi
# 13  100000100      hội pháp sư ngoại truyện
# 14  100000115                   thám tử sói
# 15  100000117            cuộc giải cứu cuối
# 16  100000142            bản tin trang nhất
# 17  100000143          chấp pháp tiên phong
# 18  100000148   kẻ trộm mộ  huyền thoại trở
# 19  100000162     ngày cuối chuyến lưu diễn
#
#                                           description  \
# 0   sang min dân mỹ thuật  tính đào hoa thích đuổi...
# 1   tập phim chân elizabeth  công chúa thứ  vương ...
# 2   murakami luôn ám ảnh người bạn thuở nhỏ   kuro...
# 3   cô nàng  sát giai   mánh lới  dắt mũi  đàn ông...
# 4   học sinh lớp e  bước học kỳ thứ   họ nhận nhiệ...
# 5   trong tập trận ở hawaii   cơn bão siêu nhiên x...
# 6   tài tử điện ảnh số  hồng kông tiếp tục màn hóa...
# 7   marc sở hữu gần mọi thứ  người đàn ông trung n...
# 8   lee jung jin   cảnh sát nắm đấm đi lời nói  jo...
# 9   quy tụ dàn diễn viên  hot   phim xoay quanh ân...
# 10  umaru  cô  hot girl  xinh đẹp mới  tuổi nổi ti...
# 11  vụ nổ mỏ  loài khủng long tưởng tuyệt chủng bỗ...
# 12  bản tình ca tuyệt đẹp ca ngợi mối tình biên gi...
# 13  chuyển thể phần ngoại truyện bộ truyện tranh t...
# 14  lai tạo giữa người sói  hiroshi khả năng đánh ...
# 15  o lâu ngày đổ bộ   người người lính mỹ  quân y...
# 16  bạn trai ling đột ngột đời trong  tai nạn xe h...
# 17  bất mãn pháp luật dường bảo vệ kẻ xấu  nhằm đò...
# 18  phim trông đợi nhất nhì   chuyển thể tiểu thuy...
# 19  phim kể về cuộc phỏng vấn kéo dài  ngày giữa p...
#
#                           title2  \
# 0                   co dau  tuoi
# 1                   that dai toi
# 2         co gai ngoai hanh tinh
# 3                       phan yeu
# 4                 lop hoc am sat
# 5                      giay cuoi
# 6    vua bip dai chien las vegas
# 7                            yeu
# 8                   com luu manh
# 9                         yeu de
# 10                   em gai  mat
# 11  cao boi dai chien khung long
# 12       mat xco va tinh yeu toi
# 13      hoi phap su ngoai truyen
# 14                   tham tu soi
# 15            cuoc giai cuu cuoi
# 16            ban tin trang nhat
# 17          chap phap tien phong
# 18   ke trom mo  huyen thoai tro
# 19     ngay cuoi chuyen luu dien
#
#                                          description2
# 0   sang min dan my thuat  tinh dao hoa thich duoi...
# 1   tap phim chan elizabeth  cong chua thu  vuong ...
# 2   murakami luon am anh nguoi ban thuo nho   kuro...
# 3   co nang  sat giai   manh loi  dat mui  dan ong...
# 4   hoc sinh lop e  buoc hoc ky thu   ho nhan nhie...
# 5   trong tap tran o hawaii   con bao sieu nhien x...
# 6   tai tu dien anh so  hong kong tiep tuc man hoa...
# 7   marc so huu gan moi thu  nguoi dan ong trung n...
# 8   lee jung jin   canh sat nam dam di loi noi  jo...
# 9   quy tu dan dien vien  hot   phim xoay quanh an...
# 10  umaru  co  hot girl  xinh dep moi  tuoi noi ti...
# 11  vu no mo  loai khung long tuong tuyet chung bo...
# 12  ban tinh ca tuyet dep ca ngoi moi tinh bien gi...
# 13  chuyen the phan ngoai truyen bo truyen tranh t...
# 14  lai tao giua nguoi soi  hiroshi kha nang danh ...
# 15  o lau ngay do bo   nguoi nguoi linh my  quan y...
# 16  ban trai ling dot ngot doi trong  tai nan xe h...
# 17  bat man phap luat duong bao ve ke xau  nham do...
# 18  phim trong doi nhat nhi   chuyen the tieu thuy...
# 19  phim ke ve cuoc phong van keo dai  ngay giua p...

# %% [markdown]
# # Tách từ Tiếng Việt

# %%
def str_tokenizer(string):
    gram_str = list(ViTokenizer.tokenize(string.decode('utf-8')).split())
    return gram_str
df["token_title"] = df.title.apply(lambda t : str_tokenizer(t))
df["token_description"] = df.description.apply(lambda t : str_tokenizer(t))
df.head(20)
# Out:
#         index                         title  \
# 0   100000008                  cô dâu  tuổi
# 1   100000019                  thất đại tội
# 2   100000026        cô gái ngoài hành tinh
# 3   100000031                      phần yêu
# 4   100000042                lớp học ám sát
# 5   100000050                     giây cuối
# 6   100000054   vua bịp đại chiến las vegas
# 7   100000059                           yêu
# 8   100000061                  cớm lưu manh
# 9   100000069                        yêu dễ
# 10  100000071                   em gái  mặt
# 11  100000072  cao bồi đại chiến khủng long
# 12  100000080       mat xcơ va tình yêu tôi
# 13  100000100      hội pháp sư ngoại truyện
# 14  100000115                   thám tử sói
# 15  100000117            cuộc giải cứu cuối
# 16  100000142            bản tin trang nhất
# 17  100000143          chấp pháp tiên phong
# 18  100000148   kẻ trộm mộ  huyền thoại trở
# 19  100000162     ngày cuối chuyến lưu diễn
#
#                                           description  \
# 0   sang min dân mỹ thuật  tính đào hoa thích đuổi...
# 1   tập phim chân elizabeth  công chúa thứ  vương ...
# 2   murakami luôn ám ảnh người bạn thuở nhỏ   kuro...
# 3   cô nàng  sát giai   mánh lới  dắt mũi  đàn ông...
# 4   học sinh lớp e  bước học kỳ thứ   họ nhận nhiệ...
# 5   trong tập trận ở hawaii   cơn bão siêu nhiên x...
# 6   tài tử điện ảnh số  hồng kông tiếp tục màn hóa...
# 7   marc sở hữu gần mọi thứ  người đàn ông trung n...
# 8   lee jung jin   cảnh sát nắm đấm đi lời nói  jo...
# 9   quy tụ dàn diễn viên  hot   phim xoay quanh ân...
# 10  umaru  cô  hot girl  xinh đẹp mới  tuổi nổi ti...
# 11  vụ nổ mỏ  loài khủng long tưởng tuyệt chủng bỗ...
# 12  bản tình ca tuyệt đẹp ca ngợi mối tình biên gi...
# 13  chuyển thể phần ngoại truyện bộ truyện tranh t...
# 14  lai tạo giữa người sói  hiroshi khả năng đánh ...
# 15  o lâu ngày đổ bộ   người người lính mỹ  quân y...
# 16  bạn trai ling đột ngột đời trong  tai nạn xe h...
# 17  bất mãn pháp luật dường bảo vệ kẻ xấu  nhằm đò...
# 18  phim trông đợi nhất nhì   chuyển thể tiểu thuy...
# 19  phim kể về cuộc phỏng vấn kéo dài  ngày giữa p...
#
#                          token_title  \
# 0                     [cô_dâu, tuổi]
# 1                    [thất, đại_tội]
# 2        [cô, gái, ngoài, hành_tinh]
# 3                        [phần, yêu]
# 4                  [lớp_học, ám_sát]
# 5                       [giây, cuối]
# 6   [vua, bịp, đại_chiến, las_vegas]
# 7                              [yêu]
# 8                    [cớm, lưu_manh]
# 9                          [yêu, dễ]
# 10                     [em_gái, mặt]
# 11  [cao_bồi, đại_chiến, khủng_long]
# 12     [mat, xcơ, va, tình_yêu, tôi]
# 13     [hội, pháp_sư, ngoại, truyện]
# 14                    [thám_tử, sói]
# 15            [cuộc, giải_cứu, cuối]
# 16            [bản, tin, trang_nhất]
# 17          [chấp, pháp, tiên_phong]
# 18   [kẻ_trộm, mộ, huyền_thoại, trở]
# 19    [ngày, cuối, chuyến, lưu_diễn]
#
#                                     token_description
# 0   [sang, min, dân, mỹ_thuật, tính, đào_hoa, thíc...
# 1   [tập, phim, chân, elizabeth, công_chúa, thứ, v...
# 2   [murakami, luôn, ám_ảnh, người, bạn, thuở, nhỏ...
# 3   [cô, nàng, sát, giai, mánh_lới, dắt_mũi, đàn_ô...
# 4   [học_sinh, lớp, e, bước, học_kỳ, thứ, họ, nhận...
# 5   [trong, tập_trận, ở, hawaii, cơn, bão, siêu_nh...
# 6   [tài_tử, điện_ảnh, số, hồng, kông, tiếp_tục, m...
# 7   [marc, sở_hữu, gần, mọi, thứ, người, đàn_ông, ...
# 8   [lee, jung, jin, cảnh_sát, nắm_đấm, đi, lời_nó...
# 9   [quy_tụ, dàn, diễn_viên, hot_phim, xoay, quanh...
# 10  [umaru, cô, hot_girl, xinh_đẹp, mới, tuổi, nổi...
# 11  [vụ, nổ, mỏ, loài, khủng_long, tưởng, tuyệt_ch...
# 12  [bản, tình_ca, tuyệt, đẹp, ca_ngợi, mối, tình,...
# 13  [chuyển_thể, phần, ngoại, truyện, bộ, truyện_t...
# 14  [lai_tạo, giữa, người, sói, hiroshi, khả_năng,...
# 15  [o, lâu, ngày, đổ_bộ, người_người, lính, mỹ, q...
# 16  [bạn, trai, ling, đột_ngột, đời, trong, tai_nạ...
# 17  [bất_mãn, pháp_luật, dường, bảo_vệ, kẻ, xấu, n...
# 18  [phim, trông_đợi, nhất, nhì, chuyển_thể, tiểu_...
# 19  [phim, kể, về, cuộc, phỏng_vấn, kéo_dài, ngày,...

# %% [markdown]
# # Train data

# %%
from gensim.models import Word2Vec
df["context"] = df["token_title"] + df["token_description"]
train_data = df.context.tolist()
model = Word2Vec(train_data, size=100, window=10, min_count=3, workers=4, sg=1)

# %%
def similar_by_word(word):
    u = [x for x in model.wv.similar_by_word(word)]
    print word
    for i in u:
        print i[0],i[1]
strs = "lớp học ám sát (phần 4)"
s = transform_row(strs).decode('utf-8')
list = ViTokenizer.tokenize(s).split()
for word in list:
    similar_by_word(word)
# Out:
# lớp_học
# giảng_dạy 0.976852059364
# saburo 0.975131988525
# tôn_thờ 0.974249303341
# trí_tuệ 0.973558366299
# makoto 0.973522245884
# ten 0.973095178604
# chế_giễu 0.972650527954
# yato 0.972461342812
# nam_sinh 0.972244083881
# hướng_dẫn 0.972207784653
# ám_sát
# cia 0.94836461544
# rửa_tiền 0.942266702652
# an_ninh 0.936377644539
# tối_mật 0.929275870323
# imf 0.92894256115
# truy_lùng 0.92882925272
# đạn 0.924883782864
# chiến_dịch 0.92385840416
# sĩ_quan 0.920827746391
# mua_bán 0.919986307621

# %% [markdown]
# # Tf-idf (Bonus)

# %%
#count
from collections import Counter
all_word = []
for sentence in train_data:
    all_word+=sentence
counts = Counter(all_word)
ndoc = 4719 
sentence_1 = df.token_description.iloc[1]
v =  set(sentence_1)
for word in v:
    print word, (ndoc / float(counts[word]))* (sentence_1.count(word) / float(len(sentence_1)))
# Out:
# người 0.0371530921545
# bé_nhỏ 11.2357142857
# hành_trình 0.501221455125
# nào 0.596586599241
# cân_bằng 33.7071428571
# đi 0.15937183384
# thất 7.93109243697
# đại 1.21467181467
# thế 0.564136282128
# trong 0.043297550234
# tội 3.21020408163
# ngày 0.230476190476
# thế_lực 1.26008010681
# nhờ 0.97701863354
# giành 1.03714285714
# liones 67.4142857143
# elizabeth 10.3714285714
# về 0.0656419529837
# công_chúa 3.09950738916
# chân 0.97701863354
# tay 0.406110154905
# bạn 0.137861524978
# nàng 0.373486347448
# đặc_biệt 0.578663396689
# vương_quốc 6.57700348432
# hắc_ám 8.98857142857
# thế_giới 0.262823725982
# tập 2.93105590062
# phim 0.0483256528418
# giúp 0.615655577299
# thứ 0.41106271777
# còn 0.179532052501
# tìm 0.154975369458

# %%
#Word2Vec cho tiếng việt không dấu

# %%
df2 = pd.read_csv('dataNLP.csv', header=None,names=['index','title','description'])
